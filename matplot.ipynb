# %%
import numpy as np
import pandas as pd
import hvplot.pandas
from pathlib import Path
import matplotlib.pyplot as plt
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(> .cell-output-ipywidget-background
#     > .lm-Widget
#     > *[data-root-id]),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
# open csv to pandas df 
file_path = Path("prediction_m1.csv")
m1_predic = pd.read_csv(file_path)
m1_predic.head(3)

file_path = Path("prediction_m2.csv")
m2_predic = pd.read_csv(file_path)

m1_predic = m1_predic.rename(columns={'Predictions': 'Machine1'})
m1_predic['Machine2'] = m2_predic["Predictions"]
m1_predic.head(3)
# Out:
#    Unnamed: 0 setCode  price  Common  Rare  Uncommon  Mythical  Angle  Other  \
# 0           0     XLN    328     125    75        82        17      0    256
# 1           1     XLN    332     125    75        82        17      0    256
# 2           2     XLN    331     125    75        82        17      0    256
#
#    Human  Zombies  week_num  Machine1  Machine2
# 0     43        0         1       328       328
# 1     43        0         2       328       328
# 2     43        0         3       328       332

# %%
xln_df = m1_predic.loc[m1_predic['setCode'] == "XLN"]
plt.plot(xln_df['week_num'], xln_df['Machine1'], color='blue', label='Machine 1')
plt.plot(xln_df['week_num'], xln_df['price'], color='red', label='actual')
plt.plot(xln_df['week_num'], xln_df['Machine2'], color='green', label='Machine 2')
plt.xlabel('Week Number')
plt.ylabel('Price')
plt.legend(loc="upper right")
plt.title('XLN Data')
plt.savefig('XLN.png')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
xln_df = m1_predic.loc[m1_predic['setCode'] == "KHM"]
plt.plot(xln_df['week_num'], xln_df['Machine1'], color='blue', label='Machine 1')
plt.plot(xln_df['week_num'], xln_df['price'], color='red', label='actual')
plt.plot(xln_df['week_num'], xln_df['Machine2'], color='green', label='Machine 2')
plt.xlabel('Week Number')
plt.ylabel('Price')
plt.legend(loc="upper right")
plt.title('KHM Data')
plt.savefig('KHM.png')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
xln_df = m1_predic.loc[m1_predic['setCode'] == "MID"]
plt.plot(xln_df['week_num'], xln_df['Machine1'], color='blue', label='Machine 1')
plt.plot(xln_df['week_num'], xln_df['price'], color='red', label='actual')
plt.plot(xln_df['week_num'], xln_df['Machine2'], color='green', label='Machine 2')
plt.xlabel('Week Number')
plt.ylabel('Price')
plt.legend(loc="upper right")
plt.title('MID Data')
plt.savefig('MID.png')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
xln_df = m1_predic.loc[m1_predic['setCode'] == "NEO"]
plt.plot(xln_df['week_num'], xln_df['Machine1'], color='blue', label='Machine 1')
plt.plot(xln_df['week_num'], xln_df['price'], color='red', label='actual')
plt.plot(xln_df['week_num'], xln_df['Machine2'], color='green', label='Machine 2')
plt.xlabel('Week Number')
plt.ylabel('Price')
plt.legend(loc="upper right")
plt.title('NEO Data')
plt.savefig('NEO.png')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
xln_df = m1_predic.loc[m1_predic['setCode'] == "WAR"]
plt.plot(xln_df['week_num'], xln_df['Machine1'], color='blue', label='Machine 1')
plt.plot(xln_df['week_num'], xln_df['price'], color='red', label='actual')
plt.plot(xln_df['week_num'], xln_df['Machine2'], color='green', label='Machine 2')
plt.xlabel('Week Number')
plt.ylabel('Price')
plt.legend(loc="upper right")
plt.title('WAR Data')
plt.savefig('WAR.png')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#open predict csv and actual and combine
# open csv to pandas df 
file_path = Path("m1VOW-pre.csv")
m1a_predic = pd.read_csv(file_path)

file_path = Path("m2VOW-pre.csv")
m2a_predic = pd.read_csv(file_path)

file_path = Path("m3VOW-pre.csv")
m3a_predic = pd.read_csv(file_path)


file_path = Path("vow_actual.csv")
actual = pd.read_csv(file_path)

m1a_predic = m1a_predic.rename(columns={'Price Prediction': 'Machine1'})
m1a_predic['actual price'] = actual["price"]
m1a_predic['Machine2'] = m2a_predic ["Price Prediction"]
m1a_predic['Machine3'] = m3a_predic ["Price Prediction"]
m1a_predic.head(25)
# Out:
#     Unnamed: 0  KHM  MID  NEO  VOW  WAR  XLN  Common  Rare  Uncommon  \
# 0            0    0    0    0    1    0    0     142   168       137
# 1            1    0    0    0    1    0    0     142   168       137
# 2            2    0    0    0    1    0    0     142   168       137
# 3            3    0    0    0    1    0    0     142   168       137
# 4            4    0    0    0    1    0    0     142   168       137
# 5            5    0    0    0    1    0    0     142   168       137
# 6            6    0    0    0    1    0    0     142   168       137
# 7            7    0    0    0    1    0    0     142   168       137
# 8            8    0    0    0    1    0    0     142   168       137
# 9            9    0    0    0    1    0    0     142   168       137
# 10          10    0    0    0    1    0    0     142   168       137
# 11          11    0    0    0    1    0    0     142   168       137
# 12          12    0    0    0    1    0    0     142   168       137
# 13          13    0    0    0    1    0    0     142   168       137
# 14          14    0    0    0    1    0    0     142   168       137
# 15          15    0    0    0    1    0    0     142   168       137
# 16          16    0    0    0    1    0    0     142   168       137
# 17          17    0    0    0    1    0    0     142   168       137
# 18          18    0    0    0    1    0    0     142   168       137
# 19          19    0    0    0    1    0    0     142   168       137
# 20          20    0    0    0    1    0    0     142   168       137
# 21          21    0    0    0    1    0    0     142   168       137
# 22          22    0    0    0    1    0    0     142   168       137
# 23          23    0    0    0    1    0    0     142   168       137
# 24          24    0    0    0    1    0    0     142   168       137
#
#     Mythical  Angle  Other  Human  Zombies  week_num  Machine1  actual price  \
# 0         58      1    389     84       31         1       316           344
# 1         58      1    389     84       31         2       316           316
# 2         58      1    389     84       31         3       316           307
# 3         58      1    389     84       31         4       316           293
# 4         58      1    389     84       31         5       316           289
# 5         58      1    389     84       31         6       316           288
# 6         58      1    389     84       31         7       316           286
# 7         58      1    389     84       31         8       316           286
# 8         58      1    389     84       31         9       316           277
# 9         58      1    389     84       31        10       316           270
# 10        58      1    389     84       31        11       316           267
# 11        58      1    389     84       31        12       316           259
# 12        58      1    389     84       31        13       316           264
# 13        58      1    389     84       31        14       316           288
# 14        58      1    389     84       31        15       316           283
# 15        58      1    389     84       31        16       316           280
# 16        58      1    389     84       31        17       316           276
# 17        58      1    389     84       31        18       316           269
# 18        58      1    389     84       31        19       316           270
# 19        58      1    389     84       31        20       316           269
# 20        58      1    389     84       31        21       316           284
# 21        58      1    389     84       31        22       308           275
# 22        58      1    389     84       31        23       307           283
# 23        58      1    389     84       31        24       307           280
# 24        58      1    389     84       31        25       307           278
#
#     Machine2  Machine3
# 0        316       316
# 1        316       316
# 2        316       316
# 3        316       316
# 4        316       316
# 5        316       316
# 6        308       316
# 7        308       316
# 8        308       316
# 9        308       316
# 10       308       316
# 11       308       316
# 12       308       316
# 13       308       316
# 14       308       308
# 15       308       308
# 16       308       308
# 17       308       308
# 18       308       308
# 19       308       308
# 20       308       308
# 21       308       308
# 22       308       308
# 23       287       308
# 24       287       308

# %%
plt.plot(m1a_predic['week_num'], m1a_predic['Machine1'], color='blue', label='Machine 1')
plt.plot(m1a_predic['week_num'], m1a_predic['actual price'], color='red', label='actual')
plt.plot(m1a_predic['week_num'], m1a_predic['Machine2'], color='green', label='Machine 2')
plt.xlabel('Week Number')
plt.ylabel('Price')
plt.legend(loc="upper right")
plt.title('VOW Data')
plt.savefig('VOW.png')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
accuracy_df = m1a_predic[['week_num','Machine1', 'actual price']].copy()
accuracy_df.tail(3)
# Out:
#     week_num  Machine1  actual price
# 22        23       307           283
# 23        24       307           280
# 24        25       307           278

# %%
accuracy_df['Percentage'] = (accuracy_df['actual price'] / accuracy_df['Machine1'] * 100 -100).round(2)
accuracy_df.tail(3)
# Out:
#     week_num  Machine1  actual price  Percentage
# 22        23       307           283       -7.82
# 23        24       307           280       -8.79
# 24        25       307           278       -9.45

# %%
nonegs = []
for i in accuracy_df['Percentage']:
    if i >= 0:
        nonegs.append(i)
    if i < 0:
        i = i * -1
        nonegs.append(i)
accuracy_df['Machine1'] = nonegs
accuracy_df.head(10)
# Out:
#    week_num  Machine1  actual price  Percentage
# 0         1      8.86           344        8.86
# 1         2      0.00           316        0.00
# 2         3      2.85           307       -2.85
# 3         4      7.28           293       -7.28
# 4         5      8.54           289       -8.54
# 5         6      8.86           288       -8.86
# 6         7      9.49           286       -9.49
# 7         8      9.49           286       -9.49
# 8         9     12.34           277      -12.34
# 9        10     14.56           270      -14.56

# %%
avg=  accuracy_df['Machine1'].mean()
print(f'the Machine1 average error is {avg}')
# Out:
# the Machine1 average error is 10.6732

# %%
# calculate accuracy machine 2
accuracy_df['Machine2'] = m1a_predic['Machine2']
accuracy_df['Percentage2'] = (accuracy_df['actual price'] / accuracy_df['Machine2'] * 100 -100).round(2)

accuracy_df['Machine3'] = m1a_predic['Machine3']
accuracy_df['Percentage3'] = (accuracy_df['actual price'] / accuracy_df['Machine3'] * 100 -100).round(2)

accuracy_df.tail(3)
# Out:
#     week_num  Machine1  actual price  Percentage  Machine2  Percentage2  \
# 22        23      7.82           283       -7.82       308        -8.12
# 23        24      8.79           280       -8.79       287        -2.44
# 24        25      9.45           278       -9.45       287        -3.14
#
#     Machine3  Percentage3
# 22       308        -8.12
# 23       308        -9.09
# 24       308        -9.74

# %%
nonegs = []
for i in accuracy_df['Percentage2']:
    if i >= 0:
        nonegs.append(i)
    if i < 0:
        i = i * -1
        nonegs.append(i)
accuracy_df['Machine2n-'] = nonegs
accuracy_df.tail(10)
# Out:
#     week_num  Machine1  actual price  Percentage  Machine2  Percentage2  \
# 15        16     11.39           280      -11.39       308        -9.09
# 16        17     12.66           276      -12.66       308       -10.39
# 17        18     14.87           269      -14.87       308       -12.66
# 18        19     14.56           270      -14.56       308       -12.34
# 19        20     14.87           269      -14.87       308       -12.66
# 20        21     10.13           284      -10.13       308        -7.79
# 21        22     10.71           275      -10.71       308       -10.71
# 22        23      7.82           283       -7.82       308        -8.12
# 23        24      8.79           280       -8.79       287        -2.44
# 24        25      9.45           278       -9.45       287        -3.14
#
#     Machine3  Percentage3  Machine2n-
# 15       308        -9.09        9.09
# 16       308       -10.39       10.39
# 17       308       -12.66       12.66
# 18       308       -12.34       12.34
# 19       308       -12.66       12.66
# 20       308        -7.79        7.79
# 21       308       -10.71       10.71
# 22       308        -8.12        8.12
# 23       308        -9.09        2.44
# 24       308        -9.74        3.14

# %%
avg=  accuracy_df['Machine2n-'].mean()
print(f'the Machine2 average error is {avg}')
# Out:
# the Machine2 average error is 8.8212

# %%
# calculate average for machine 3
nonegs = []
for i in accuracy_df['Percentage3']:
    if i >= 0:
        nonegs.append(i)
    if i < 0:
        i = i * -1
        nonegs.append(i)
accuracy_df['Machine3n-'] = nonegs
accuracy_df.tail(25)
# Out:
#     week_num  Machine1  actual price  Percentage  Machine2  Percentage2  \
# 0          1      8.86           344        8.86       316         8.86
# 1          2      0.00           316        0.00       316         0.00
# 2          3      2.85           307       -2.85       316        -2.85
# 3          4      7.28           293       -7.28       316        -7.28
# 4          5      8.54           289       -8.54       316        -8.54
# 5          6      8.86           288       -8.86       316        -8.86
# 6          7      9.49           286       -9.49       308        -7.14
# 7          8      9.49           286       -9.49       308        -7.14
# 8          9     12.34           277      -12.34       308       -10.06
# 9         10     14.56           270      -14.56       308       -12.34
# 10        11     15.51           267      -15.51       308       -13.31
# 11        12     18.04           259      -18.04       308       -15.91
# 12        13     16.46           264      -16.46       308       -14.29
# 13        14      8.86           288       -8.86       308        -6.49
# 14        15     10.44           283      -10.44       308        -8.12
# 15        16     11.39           280      -11.39       308        -9.09
# 16        17     12.66           276      -12.66       308       -10.39
# 17        18     14.87           269      -14.87       308       -12.66
# 18        19     14.56           270      -14.56       308       -12.34
# 19        20     14.87           269      -14.87       308       -12.66
# 20        21     10.13           284      -10.13       308        -7.79
# 21        22     10.71           275      -10.71       308       -10.71
# 22        23      7.82           283       -7.82       308        -8.12
# 23        24      8.79           280       -8.79       287        -2.44
# 24        25      9.45           278       -9.45       287        -3.14
#
#     Machine3  Percentage3  Machine2n-  Machine3n-
# 0        316         8.86        8.86        8.86
# 1        316         0.00        0.00        0.00
# 2        316        -2.85        2.85        2.85
# 3        316        -7.28        7.28        7.28
# 4        316        -8.54        8.54        8.54
# 5        316        -8.86        8.86        8.86
# 6        316        -9.49        7.14        9.49
# 7        316        -9.49        7.14        9.49
# 8        316       -12.34       10.06       12.34
# 9        316       -14.56       12.34       14.56
# 10       316       -15.51       13.31       15.51
# 11       316       -18.04       15.91       18.04
# 12       316       -16.46       14.29       16.46
# 13       316        -8.86        6.49        8.86
# 14       308        -8.12        8.12        8.12
# 15       308        -9.09        9.09        9.09
# 16       308       -10.39       10.39       10.39
# 17       308       -12.66       12.66       12.66
# 18       308       -12.34       12.34       12.34
# 19       308       -12.66       12.66       12.66
# 20       308        -7.79        7.79        7.79
# 21       308       -10.71       10.71       10.71
# 22       308        -8.12        8.12        8.12
# 23       308        -9.09        2.44        9.09
# 24       308        -9.74        3.14        9.74

# %%
avg=  accuracy_df['Machine3n-'].mean()
print(f'the Machine3 average error is {avg}')
# Out:
# the Machine3 average error is 10.074000000000002
